# %%
import pandas as pd
import numpy as np
import matplotlib as plt
from matplotlib import pyplot

path = 'C:\\Users\\DeLL\\Desktop\\python\\jsrt_metadata.csv'
df = pd.read_csv(path,header=0)

df['diagnosis']

mx = df['diagnosis'].value_counts().idxmax()
df['diagnosis'].replace(np.nan, mx, inplace=True)

plt.pyplot.hist(df['diagnosis'].value_counts())
# Out:
# (array([30.,  1.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  1.]),
#  array([  1. ,  15.8,  30.6,  45.4,  60.2,  75. ,  89.8, 104.6, 119.4,
#         134.2, 149. ]),
#  <BarContainer object of 10 artists>)

# %%
df['state'].value_counts()
# Out:
# malignant     100
# non-nodule     93
# benign         54
# Name: state, dtype: int64

# %%
plt.pyplot.pie(df['state'].value_counts(), explode = [0.0,0.1,0.0], labels = ['malignant', 'non-module','benign'], shadow = True, autopct = '%1.1f%%', startangle = 90)
# Out:
# ([<matplotlib.patches.Wedge at 0x28e7ee47070>,
# ...
#  [Text(-1.051228217420429, 0.32391238769004665, 'malignant'),
#   Text(0.6627131763988918, -1.0004055406820234, 'non-module'),
#   Text(0.6974946049230534, 0.8505887820229197, 'benign')],
#  [Text(-0.5733972095020522, 0.17667948419457088, '40.5%'),
#   Text(0.3865826862326868, -0.5835698987311803, '37.7%'),
#   Text(0.3804516026853018, 0.46395751746704705, '21.9%')])

# %%
df['gender'].value_counts()
# Out:
# Female    128
# Male      119
# Name: gender, dtype: int64

# %%
plt.pyplot.pie(df['gender'].value_counts(), explode = [0.0,0.1], labels = ['Female', 'Male'],shadow = True, autopct = '%1.1f%%', startangle = 90)
# Out:
# ([<matplotlib.patches.Wedge at 0x28e7edfe820>,
# ...
#  [Text(-1.098198743276378, -0.06292471903937331, 'Female'),
#   Text(1.1980349926651397, 0.06864514804295202, 'Male')],
#  [Text(-0.5990174963325697, -0.03432257402147635, '51.8%'),
#   Text(0.6988537457213314, 0.04004300302505534, '48.2%')])
